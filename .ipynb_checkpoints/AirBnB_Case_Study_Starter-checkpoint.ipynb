# %% [markdown]
# # AirBnB NY Locations Data Case Study
#
# In this final project, you task will be to take the data provided and find evidence to answer the following questions.
#
# 1. How many neighborhood groups are there and which shows up the most?
# 2. Are private rooms the most popular in Manhattan?
# 3. Who are the top 10 busiest hosts based on number of reviews per month?
# 4. Which neighorhood group has the highest average price? Plot the average prices in a professional looking bar chart
# 5. What is the most expensive neighbourhood in each neighbourhood group?
# 6. Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
# 7. Who currently has no (zero) availability with a review count of 100 or more?
# 8. If each host rents all of their properties for the night, which 5 make the most that night?
# 9. When did Danielle from Queens last receive a review?
# 10. Display a bar chart showing the number of each type of room in the Bronx
#
# You will be given **4 hours** to complete this assignment.
# **Be Advised** I will go dark for this entire assignment time period. That said, any questions that you would like to ask about the data, or the project **MUST** be asked before the time starts. Once the time has started, I can no longer give information.
#
# This is to simulate what you will face when you are out in the wild.
#
# Happy Coding!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
air_bnb = pd.read_csv('./AB_NYC_2019.csv')
air_bnb.head()
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
#
#      host_name neighbourhood_group neighbourhood  latitude  longitude  \
# 0         John            Brooklyn    Kensington  40.64749  -73.97237
# 1     Jennifer           Manhattan       Midtown  40.75362  -73.98377
# 2    Elisabeth           Manhattan        Harlem  40.80902  -73.94190
# 3  LisaRoxanne            Brooklyn  Clinton Hill  40.68514  -73.95976
# 4        Laura           Manhattan   East Harlem  40.79851  -73.94399
#
#          room_type  price  minimum_nights  number_of_reviews last_review  \
# 0     Private room    149               1                  9  2018-10-19
# 1  Entire home/apt    225               1                 45  2019-05-21
# 2     Private room    150               3                  0         NaN
# 3  Entire home/apt     89               1                270  2019-07-05
# 4  Entire home/apt     80              10                  9  2018-11-19
#
#    reviews_per_month  calculated_host_listings_count  availability_365
# 0               0.21                               6               365
# 1               0.38                               2               355
# 2                NaN                               1               365
# 3               4.64                               1               194
# 4               0.10                               1                 0

# %%
# How many neighbourhood groups / which shows up the most
air_bnb.groupby('neighbourhood_group')['neighbourhood'].count().reset_index()
# Out:
#   neighbourhood_group  neighbourhood
# 0               Bronx           1091
# 1            Brooklyn          20104
# 2           Manhattan          21661
# 3              Queens           5666
# 4       Staten Island            373

# %%
# Are private rooms the most popular in Manhattan?
air_bnb[air_bnb['neighbourhood_group'] == 'Manhattan'].groupby(['room_type']).count()[['id']]
# Out:
#                     id
# room_type
# Entire home/apt  13199
# Private room      7982
# Shared room        480

# %%
# Who are the top 10 busiest hosts based on number of reviews per month?
air_bnb.groupby('host_name')['number_of_reviews'].count().reset_index().sort_values('number_of_reviews', ascending=False)
# Out:
#           host_name  number_of_reviews
# 7135        Michael                417
# 2376          David                403
# 9781   Sonder (NYC)                327
# 4989           John                294
# 314            Alex                279
# ...             ...                ...
# 4804        Jerbean                  1
# 4803         Jerald                  1
# 4802      Jeonghoon                  1
# 4800           Jeny                  1
# 11451            현선                  1
#
# [11452 rows x 2 columns]

# %%
# Which neighborhood group has the highest avg price and plot the average prices in a bar chart
air_bnb.groupby('neighbourhood_group')['price'].mean().reset_index().sort_values('price', ascending=False)

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
neighbourhood= ['Manhattan', 'Brooklyn', 'Staten Island', 'Queens', 'Bronx']
average_prices = [196.875814,124.383207,114.812332,99.517649,87.496792]
ax.bar(neighbourhood,average_prices)
plt.show()

# %%
# What is the most expensive neighbourhood in each neighbourhood_group
air_bnb.groupby('price').count().sort_values('price', ascending=False)
# Out:
#        id  name  host_id  host_name  neighbourhood_group  neighbourhood  \
# price
# 10000   3     3        3          3                    3              3
# 9999    3     3        3          3                    3              3
# 8500    1     1        1          1                    1              1
# 8000    1     1        1          1                    1              1
# 7703    1     1        1          1                    1              1
# ...    ..   ...      ...        ...                  ...            ...
# 13      1     1        1          1                    1              1
# 12      4     4        4          4                    4              4
# 11      3     3        3          3                    3              3
# 10     17    17       17         17                   17             17
# 0      11    11       11         11                   11             11
#
#        latitude  longitude  room_type  minimum_nights  number_of_reviews  \
# price
# 10000         3          3          3               3                  3
# 9999          3          3          3               3                  3
# 8500          1          1          1               1                  1
# 8000          1          1          1               1                  1
# 7703          1          1          1               1                  1
# ...         ...        ...        ...             ...                ...
# 13            1          1          1               1                  1
# 12            4          4          4               4                  4
# 11            3          3          3               3                  3
# 10           17         17         17              17                 17
# 0            11         11         11              11                 11
#
#        last_review  reviews_per_month  calculated_host_listings_count  \
# price
# 10000            2                  2                               3
# 9999             2                  2                               3
# 8500             1                  1                               1
# 8000             1                  1                               1
# 7703             0                  0                               1
# ...            ...                ...                             ...
# 13               1                  1                               1
# 12               1                  1                               4
# 11               1                  1                               3
# 10              12                 12                              17
# 0               10                 10                              11
#
#        availability_365
# price
# 10000                 3
# 9999                  3
# 8500                  1
# 8000                  1
# 7703                  1
# ...                 ...
# 13                    1
# 12                    4
# 11                    3
# 10                   17
# 0                    11
#
# [674 rows x 15 columns]

# %%
# Which host has the highest minimum rental? *minimal rental is based on price and minimum nights
air_bnb.groupby(['host_name','minimum_nights'])['price'].sum().reset_index().sort_values('price', ascending=True).head(10)
# Out:
#                host_name  minimum_nights  price
# 16059             Qiuchi               3      0
# 2113             Aymeric               5      0
# 13101       Martial Loft               2      0
# 13346            Maureen               5     10
# 20229  Vishanti & Jeremy               1     10
# 17273              Salim               1     10
# 16674              Rivka               7     11
# 3212            Carolann             300     12
# 4489               Dante               3     12
# 12684           Marcella               3     12

# %%
# Who has no (zero) availability with a review count of 100 or more
air_bnb[(air_bnb["number_of_reviews"]>=100) & (air_bnb["availability_365"] == 0)].head(50)
# Out:
#            id                                               name  host_id  \
# 8        5203                 Cozy Clean Guest Room - Family Apt     7490
# 94      20913                 Charming 1 bed GR8 WBurg LOCATION!    79402
# 132     30031                   NYC artists’ loft with roof deck   129352
# 174     44221                     Financial District Luxury Loft   193722
# 180     45556              Fort Greene, Brooklyn: Center Bedroom    67778
# 220     57468                    Modern, Large East Village Loft   239208
# 250     62461                        B NYC Staten Alternative...   303939
# 357     99070                Comfortable Cozy Space in El Barrio   522065
# 415    140425                       Holiday Time in NY - Oh My!!   683975
# 462    163627           Blue Room in Awesome Artist's Apartment!   242506
# 471    166172                    LG Private Room/Family Friendly   792159
# 657    250259                          Pre-War Williamsburg Loft  1311398
# 696    258284                  Fresh, Clean Brooklyn Garden Apt.  1358312
# 701    258740                   Spacious room in beautiful apt!   1360043
# 787    282443                     QT STUDIO FOR ROMANTIC COUPLES    36897
# 802    286838                         Private Room in Brownstone  1492339
# 813    289665                Decorators 5-Star Flat West Village  1503831
# 890    322037                 Luxury Williamsburg, Brooklyn LOFT  1649300
# 969    386799                  Midtown NYC - 1 Bedroom Apartment  1935605
# 973    387735                  LOCATION LOCATION LOCATION Sara's  1146958
# 1084   455801  Hello! Cozy-Singles NYC- Upper Manhattan- Harl...  2265770
# 1089   457829    Beautiful apartment in the heart of The Village  2275829
# 1134   480549                         Studio 54, Cozy Room For 2  2361715
# 1242   531091               King size bedroom in 2 bed apartment  1787284
# 1416   635282                  Huge factory loft, prime location  1215949
# 1437   645075                      Hell's Kitchen, Midtown west!  2494666
# 1533   695216                    Private Suite in Historic House  3558158
# 1603   728409                    Huge Room in South Williamsburg  3778274
# 1630   741783                       LOVELY 2BR West Village Apt!  3880974
# 1655   752202                 Historic Mansion, Comfortable Room  3955766
# 1727   783202                Charming Apt off Bleecker, First Fl  4129805
# 1825   816637  Big apartment with top view! 1 block from subway.  1099716
# 1933   849409                Spacious garden appartment brooklyn  4434798
# 2191  1023529                             Convenient and private  5634395
# 2274  1089542                   Private Cozy Bedroom in Brooklyn   663764
# 2351  1145134                Lovely garden bedroom in Greenpoint   585273
# 2407  1185357                Central Park Room/Bath with a View!  6482637
# 2447  1223755                 Cozy, friendly, 3 min from subway.  3571821
# 2470  1251566                                        SPACE FOR 8  6774871
# 2551  1323801                 Cozy, friendly, 3 min from subway!  3571821
# 2654  1404828                 Bohemian Paradise in Industrial BK  7581642
# 2742  1479349                 Sunny Private Room in Williamsburg  5464042
# 2800  1546945                     (1) CLEAN HOME AWAY FROM HOME!  4983320
# 2878  1645667                 Truly A Sweet Home away from Home.  8732694
# 2937  1698334      Williamsburg off Bedford/no extra $ for 2ppl!  1562642
# 2978  1734724                     Williamsburg Luxury- 30 days +  8910286
# 3009  1758391                Sunny Room, Only 1 Block to Subway!  9234456
# 3015  1763209  10mins to Manhattan, 59th St, 17mins Times Squ...  9268156
# 3188  1903249                       The heart of Manhattan - NYC  3187531
# 3704  2232697                                       Kate's Place  1726966
#
#             host_name neighbourhood_group       neighbourhood  latitude  \
# 8           MaryEllen           Manhattan     Upper West Side  40.80178
# 94         Christiana            Brooklyn        Williamsburg  40.70984
# 132               Sol            Brooklyn          Greenpoint  40.73494
# 174             Coral           Manhattan  Financial District  40.70666
# 180              Doug            Brooklyn         Fort Greene  40.68863
# 220               Ori           Manhattan        East Village  40.72821
# 250          Lissette       Staten Island       Tompkinsville  40.63627
# 357   Liz And Melissa           Manhattan         East Harlem  40.79406
# 415               Ivy            Brooklyn       Crown Heights  40.67550
# 462              Jsun            Brooklyn        Williamsburg  40.71023
# 471             Wanda            Brooklyn            Bushwick  40.70283
# 657               Ben            Brooklyn        Williamsburg  40.71840
# 696                 S            Brooklyn        Clinton Hill  40.68618
# 701          Adrienne           Manhattan              Harlem  40.81872
# 787             Lydia           Manhattan           Chinatown  40.71601
# 802             Karin           Manhattan              Harlem  40.80748
# 813              Elle           Manhattan        West Village  40.72891
# 890             James            Brooklyn        Williamsburg  40.72091
# 969               Jon           Manhattan             Midtown  40.76082
# 973               Liz           Manhattan            Gramercy  40.73677
# 1084          Jeanine           Manhattan              Harlem  40.80533
# 1089           Lorena           Manhattan        East Village  40.72917
# 1134              Ron           Manhattan     Upper West Side  40.77099
# 1242           Dragan              Queens             Astoria  40.75532
# 1416            Misty            Brooklyn        Williamsburg  40.71657
# 1437            Brian           Manhattan      Hell's Kitchen  40.76376
# 1533          Natalie            Brooklyn         Fort Greene  40.69096
# 1603    AJ And Freddy            Brooklyn        Williamsburg  40.70061
# 1630     Neil & Katie           Manhattan        West Village  40.73454
# 1655            Emily            Brooklyn  Bedford-Stuyvesant  40.67968
# 1727           Evelyn           Manhattan        West Village  40.73164
# 1825           Alvaro              Queens           Sunnyside  40.74263
# 1933          Bernard            Brooklyn    Prospect Heights  40.68099
# 2191            Sarah           Manhattan              Harlem  40.82153
# 2274            Karen            Brooklyn       East Flatbush  40.65360
# 2351           Summer            Brooklyn          Greenpoint  40.72448
# 2407          William           Manhattan     Upper West Side  40.79631
# 2447   Andy & Friends            Brooklyn  Bedford-Stuyvesant  40.69122
# 2470           Karece            Brooklyn  Bedford-Stuyvesant  40.68065
# 2551   Andy & Friends            Brooklyn  Bedford-Stuyvesant  40.69081
# 2654            Ehren            Brooklyn        Williamsburg  40.70759
# 2742           Nicole            Brooklyn        Williamsburg  40.70952
# 2800            Terri              Queens            Flushing  40.75431
# 2878          Ravanna            Brooklyn  Bedford-Stuyvesant  40.68656
# 2937            Molly            Brooklyn        Williamsburg  40.71380
# 2978             Lane            Brooklyn        Williamsburg  40.72076
# 3009           Angelo            Brooklyn  Bedford-Stuyvesant  40.69696
# 3015            DeLex              Queens             Astoria  40.76451
# 3188         Michelle           Manhattan             Chelsea  40.74676
# 3704         Katarina            Brooklyn       Crown Heights  40.67167
#
#       longitude        room_type  price  minimum_nights  number_of_reviews  \
# 8     -73.96723     Private room     79               2                118
# 94    -73.95775  Entire home/apt    100               5                168
# 132   -73.95030     Private room     50               3                193
# 174   -74.01374  Entire home/apt    196               3                114
# 180   -73.97691     Private room     65               2                206
# 220   -73.98701  Entire home/apt    189               3                205
# 250   -74.08543     Private room     37               2                147
# 357   -73.94102      Shared room     65               7                131
# 415   -73.95878     Private room     79               2                115
# 462   -73.96665     Private room     89               3                205
# 471   -73.92131     Private room     60               3                480
# 657   -73.96019  Entire home/apt    295               5                125
# 696   -73.96144  Entire home/apt    154               3                233
# 701   -73.94567     Private room     58               1                143
# 787   -73.99123  Entire home/apt     90               3                107
# 802   -73.95589     Private room     75               2                101
# 813   -74.00293  Entire home/apt    450              20                157
# 890   -73.95814  Entire home/apt    325               2                320
# 969   -73.97548  Entire home/apt    250               3                116
# 973   -73.98084  Entire home/apt    125              30                128
# 1084  -73.95204     Private room     65               4                109
# 1089  -73.98811  Entire home/apt    210               1                178
# 1134  -73.98980     Private room     99               3                117
# 1242  -73.91603     Private room    109              30                304
# 1416  -73.96264  Entire home/apt    165               2                179
# 1437  -73.99161     Private room    140               2                248
# 1533  -73.97241  Entire home/apt    134               2                119
# 1603  -73.95520     Private room     65               2                164
# 1630  -74.00365  Entire home/apt    350               1                237
# 1655  -73.94715     Private room    100               1                113
# 1727  -74.00327  Entire home/apt    190               2                185
# 1825  -73.92476  Entire home/apt     85               2                108
# 1933  -73.97446  Entire home/apt    120               5                145
# 2191  -73.95512     Private room     52               3                163
# 2274  -73.94883     Private room     47               2                248
# 2351  -73.94328     Private room     99               5                179
# 2407  -73.96152     Private room     85               3                118
# 2447  -73.95648      Shared room     35               5                110
# 2470  -73.95154  Entire home/apt    165               3                130
# 2551  -73.95627      Shared room     35               5                120
# 2654  -73.92678     Private room     99               2                189
# 2742  -73.95078     Private room     80               3                130
# 2800  -73.83131     Private room     59               1                116
# 2878  -73.95348  Entire home/apt    130               3                220
# 2937  -73.96251     Private room     82               2                144
# 2978  -73.95614  Entire home/apt    180              30                183
# 3009  -73.93577     Private room     80               3                112
# 3015  -73.92942     Private room     86               2                107
# 3188  -74.00234     Private room     75               1                202
# 3704  -73.92434      Shared room     48               1                146
#
#      last_review  reviews_per_month  calculated_host_listings_count  \
# 8     2017-07-21               0.99                               1
# 94    2018-07-22               1.57                               1
# 132   2019-05-20               1.86                               1
# 174   2019-06-20               1.06                               1
# 180   2019-06-30               1.92                               2
# 220   2019-06-23               1.96                               1
# 250   2019-06-10               1.44                               6
# 357   2019-05-26               1.31                               2
# 415   2017-05-25               1.18                               1
# 462   2017-12-31               2.31                               3
# 471   2019-07-07               6.70                               1
# 657   2019-07-07               3.04                               1
# 696   2019-04-10               2.50                               1
# 701   2018-06-30               2.83                               1
# 787   2019-05-18               1.17                               1
# 802   2015-10-31               1.10                               1
# 813   2016-08-11               1.71                               1
# 890   2019-07-07               3.60                               1
# 969   2016-01-03               1.32                               1
# 973   2019-06-11               1.46                               4
# 1084  2018-09-19               1.25                               3
# 1089  2019-07-01               2.06                               1
# 1134  2017-12-11               1.41                               1
# 1242  2019-06-19               3.70                               1
# 1416  2019-06-17               2.20                               1
# 1437  2019-06-24               2.99                               1
# 1533  2018-01-25               1.46                               1
# 1603  2017-01-01               2.07                               2
# 1630  2018-09-16               2.96                               1
# 1655  2018-08-27               1.43                               1
# 1727  2019-06-24               2.30                               5
# 1825  2019-06-23               1.35                               1
# 1933  2019-07-01               1.82                               1
# 2191  2019-06-05               2.17                               2
# 2274  2019-05-05               3.27                               2
# 2351  2019-05-28               2.61                               1
# 2407  2019-01-23               1.61                               1
# 2447  2018-01-03               1.49                               4
# 2470  2017-12-14               1.84                               1
# 2551  2018-01-03               1.66                               4
# 2654  2017-12-20               2.63                               1
# 2742  2017-05-04               1.85                               1
# 2800  2017-09-06               1.63                               2
# 2878  2019-06-23               3.11                               2
# 2937  2019-04-02               3.37                               1
# 2978  2017-12-17               2.63                               1
# 3009  2018-01-01               1.61                               2
# 3015  2018-11-01               1.58                               1
# 3188  2019-06-05               3.19                               1
# 3704  2019-07-06               2.21                               1
#
#       availability_365
# 8                    0
# 94                   0
# 132                  0
# 174                  0
# 180                  0
# 220                  0
# 250                  0
# 357                  0
# 415                  0
# 462                  0
# 471                  0
# 657                  0
# 696                  0
# 701                  0
# 787                  0
# 802                  0
# 813                  0
# 890                  0
# 969                  0
# 973                  0
# 1084                 0
# 1089                 0
# 1134                 0
# 1242                 0
# 1416                 0
# 1437                 0
# 1533                 0
# 1603                 0
# 1630                 0
# 1655                 0
# 1727                 0
# 1825                 0
# 1933                 0
# 2191                 0
# 2274                 0
# 2351                 0
# 2407                 0
# 2447                 0
# 2470                 0
# 2551                 0
# 2654                 0
# 2742                 0
# 2800                 0
# 2878                 0
# 2937                 0
# 2978                 0
# 3009                 0
# 3015                 0
# 3188                 0
# 3704                 0

# %%
# If each host rents all of their properties for the night, which 5 make the most that night?
air_bnb.groupby(['host_name'])['price'].sum().reset_index().sort_values('price', ascending=False).head(5)
# Out:
#          host_name  price
# 9781  Sonder (NYC)  82795
# 1356    Blueground  70331
# 7135       Michael  66895
# 2376         David  65844
# 314           Alex  52563

# %%
# When did Danielle from Queens last receive a review?
air_bnb[(air_bnb["host_name"]== "Danielle") & (air_bnb["neighbourhood_group"] == 'Queens')]["last_review"]
# Out:
# 7086     2019-07-03
# 16349           NaN
# 20403    2019-07-06
# 21517    2019-07-07
# 22068    2019-07-06
# 22469    2019-07-08
# 27021    2018-01-02
# 33861    2019-06-20
# Name: last_review, dtype: object

# %%
# bar chart showing the number of room types in the Bronx
air_bnb[air_bnb['neighbourhood_group'] == 'Bronx'].groupby(['room_type']).count()[['id']]

fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
neighbourhood= ['Entire home/apt', 'Private room', 'Shared room']
average_prices = [379,652,60]
ax.bar(neighbourhood,average_prices)
plt.show()

# %% [markdown]
# # Final Conclusion
#
# In this cell, write your final conclusion for each of the questions asked.
#
# Also, if you uncovered some more details that were not asked above, please discribe them here.
#
# -- Add your conclusion --
